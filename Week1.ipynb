# %% [markdown]
# <a href="https://colab.research.google.com/github/farelkun/PCVK_Genap_2022/blob/master/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pada code awal, beberapa library yang akan digunakan adalah numpy, pandas, cv2, skimage, PIL, matpolib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["http://assets.kompasiana.com/items/album/2021/12/06/img-20211206-003013-61acf7ad62a70417584aa5d2.jpg?t=o&v=770",
        "https://cdn-2.tstatic.net/tribunnews/foto/bank/images/tanjiro-kamado-demon-slayer-kimetsu-no-yaiba-season-2.jpg",
        "https://cdn-2.tstatic.net/tribunnews/foto/bank/images/tengen-uzui-demon-slayer-kimetsu-no-yaiba.jpg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=770x220 at 0x7FD92DAE5850>
# <PIL.Image.Image image mode=RGB size=700x196 at 0x7FD92DAD2250>
# <PIL.Image.Image image mode=RGB size=700x196 at 0x7FD92DAE5F90>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image : tinggi x lebar = ", tinggi, "x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar =  196 x  350
# <PIL.Image.Image image mode=RGB size=350x196 at 0x7FD92F30E690>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255,255,255]
  
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x196 at 0x7FD92DACDDD0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int((lebar)/2)] = [255,255,255]
for y in range (tinggi):
    image_4[y,int(y*(lebar/tinggi))] = [255,255,255]
    image_4[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
final_frame2 = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
print('\n')
cv2_imshow(final_frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=700x196 at 0x7FD92F31B5D0>
# <PIL.Image.Image image mode=RGB size=700x196 at 0x7FD92DACDA50>
